# %%
# %pip install fastapi uvicorn python-multipart
# Out:
# Requirement already satisfied: fastapi in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (0.117.1)
# Requirement already satisfied: uvicorn in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (0.36.0)
# Collecting python-multipart
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from fastapi) (0.48.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from fastapi) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.8.0 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from uvicorn) (8.3.0)
# Requirement already satisfied: h11>=0.8 in /var/home/junho/Workspace/.venv/lib64/python3.13/site-packages (from uvicorn) (0.16.0)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Installing collected packages: python-multipart
# Successfully installed python-multipart-0.0.20
# Note: you may need to restart the kernel to use updated packages.

# %%
import uvicorn
import torch
from torch import nn
from torchvision import models
from fastapi import FastAPI, UploadFile, File, Form, HTTPException
import numpy as np
import json
from collections import OrderedDict

# ==============================================================================
# CONFIG
# ==============================================================================
TAIL_MODEL_PATH = "models_split/tail.pt"
NUM_CASE_CLASSES = 4
NUM_LOC_CLASSES = 9
SPLIT_LAYER_NAME = 'layer1'


# ==============================================================================
# 1. Tail 모델 아키텍처 정의
# ==============================================================================
class InternalTailModel(nn.Module):
    def __init__(self, original_backbone, split_layer_name, num_case, num_loc):
        super().__init__()
        layers = OrderedDict()
        found_split_point = False
        for name, module in original_backbone.named_children():
            if name == split_layer_name:
                found_split_point = True
                continue
            if found_split_point and name not in ['avgpool', 'fc']:
                layers[name] = module
        self.remaining_backbone = nn.Sequential(layers)
        self.avgpool = original_backbone.avgpool
        in_features = 2048
        self.case_head = nn.Linear(in_features, num_case)
        self.loc_head = nn.Linear(in_features, num_loc)
        
    def forward(self, x):
        feat = self.remaining_backbone(x)
        feat = self.avgpool(feat)
        feat = torch.flatten(feat, 1)
        case_out = self.case_head(feat)
        loc_out = self.loc_head(feat)
        return case_out, loc_out


# ==============================================================================
# 2. FastAPI 앱 및 모델 로드
# ==============================================================================
app = FastAPI()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 서버 시작 시 Tail 모델을 미리 로드
# 모델 구조를 만들기 위해 원본 ResNet50 backbone이 필요
original_backbone_for_tail = models.resnet50(weights=None).to(device)
tail_model = InternalTailModel(
    original_backbone_for_tail, SPLIT_LAYER_NAME, NUM_CASE_CLASSES, NUM_LOC_CLASSES
).to(device)
tail_model.load_state_dict(torch.load(TAIL_MODEL_PATH, map_location=device))
tail_model.eval()
print(f"Tail 모델 로드 완료. 추론 준비... (Device: {device})")


@app.post("/infer_tail")
async def infer_tail(file: UploadFile = File(...), metadata: str = Form(...)):
    try:
        meta = json.loads(metadata)
        shape = tuple(meta["original_shape"])
        dtype = np.dtype(meta["dtype"])
        data_bytes = await file.read()
        feature_np = np.frombuffer(data_bytes, dtype=dtype).reshape(shape)
        feature_tensor = torch.from_numpy(feature_np).to(device)

        with torch.no_grad():
            case_out, loc_out = tail_model(feature_tensor)
            case_pred = torch.argmax(torch.softmax(case_out, dim=1)).item()
            loc_pred = torch.argmax(torch.softmax(loc_out, dim=1)).item()
            
        return {
            "case_prediction": case_pred + 1,
            "location_prediction": loc_pred + 1
        }
    except Exception as e:
        raise HTTPException(status_code=500, detail=str(e))

if __name__ == "__main__":
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# Tail 모델 로드 완료. 추론 준비... (Device: cuda)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 88
#      85         raise HTTPException(status_code=500, detail=str(e))
#      87 if __name__ == "__main__":
# ---> 88     uvicorn.run(app, host="0.0.0.0", port=8000)
#
# File ~/Workspace/.venv/lib64/python3.13/site-packages/uvicorn/main.py:582, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     580         Multiprocess(config, target=server.run, sockets=[sock]).run()
#     581     else:
# --> 582         server.run()
#     583 except KeyboardInterrupt:
#     584     pass  # pragma: full coverage
#
# File ~/Workspace/.venv/lib64/python3.13/site-packages/uvicorn/server.py:67, in Server.run(self, sockets)
#      66 def run(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 67     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#
# File /usr/lib64/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
